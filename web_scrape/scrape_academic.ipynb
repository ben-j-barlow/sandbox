# %%
def get_url(name):
    return "https://www.research.ed.ac.uk/en/persons/" + name.replace(" ", "-").lower()

# %%
chrome_path = "/Applications/Google Chrome.app"

# Open the URL in Chrome
webbrowser.get(chrome_path).open(url)

# %%
import requests
from bs4 import BeautifulSoup

def output_interests(names_parsed):
    """Function takes a list of names, searches the University of Edinburgh research portal for each name and outputs their interests

    Args:
        names (List): Names to search
    """
    # create csv to output to
    with open("interests.csv", "w") as f:
        f.write("Name,Interests\n")
        for name in names_parsed:
            # get url
            url = get_url(name)
            # get page
            page = requests.get(url)
            # parse page
            soup = BeautifulSoup(page.content, 'html.parser')
            
            biography_header = soup.find('h3', class_='subheader', string='Biography')

            # Find the next div element after the 'Biography' subheader
            biography_div = biography_header.find_next_sibling('div')

            # Extract text from all <p> tags within the biography div
            biography_paragraphs = [p.get_text() for p in biography_div.find_all('p')]

            # write to csv
            f.write(name + "," + " ".join(biography_paragraphs).replace("\n", "") + "\n")

# %%
nms = names[0:2]

output_interests(nms)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [9], line 3
#       1 nms = names[0:2]
# ----> 3 output_interests(nms)
#
# Cell In [8], line 17, in output_interests(names_parsed)
#      15 url = get_url(name)
#      16 # get page
# ---> 17 page = requests.get(url)
#      18 # parse page
#      19 soup = BeautifulSoup(page.content, 'html.parser')
#
# File ~/opt/miniconda3/envs/tensorflow/lib/python3.9/site-packages/requests/api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# ...

# %%
names = [
    "Stefano Albrecht",
    "Cristina Alexandru",
    "Ross Anderson",
    "Stuart Anderson",
    "Pavlos Andreadis",
    "Valentina Andries",
    "Myrto Arapinis",
    "Douglas Armstrong",
    "D K Arvind",
    "David Aspinall",
    "Benjamin Bach",
    "Antonio Barbalace",
    "Peter Bell",
    "Vaishak Belle",
    "Hakan Bilen",
    "Alexandra Birch-Mayne",
    "Julian Bradfield",
    "Alan Bundy",
    "Peter Buneman",
    "Yang Cao",
    "Tara Capel",
    "Angus Chadwick",
    "James Cheney",
    "Michele Ciampi",
    "Shay Cohen",
    "Alexandru Cojocaru",
    "Murray Cole",
    "Aurora Constantin",
    "Felipe Costa Sperb",
    "Mary Cryan",
    "Jeff Dalton",
    "Vincent Danos",
    "Mina Doosti",
    "Tariq Elahi",
    "Tj Elmas",
    "Kousha Etessami",
    "Wenfei Fan",
    "Aris Filos-Ratsikas",
    "Bob Fisher",
    "Jacques Fleuriot",
    "Bjoern Franke",
    "Kobi Gal",
    "Raul Garcia-Patron Sanchez",
    "James Garforth",
    "Stephen Gilmore",
    "Michael Glienecke",
    "Nigel Goddard",
    "Sharon Goldwater",
    "Tia Gong",
    "Igor Goryanin",
    "Henry Gouk",
    "Boris Grot",
    "Paolo Guagliardo",
    "Heng Guo",
    "Michael Gutmann",
    "Helen Hastie",
    "Fengxiang He",
    "Kenneth Heafield",
    "Matthias Hennig",
    "Michael Herrmann",
    "Chris Heunen",
    "Robin Hill",
    "Jane Hillston",
    "Uta Hinrichs",
    "Michio Honda",
    "Timothy Hospedales",
    "Borislav Ikonomov",
    "Craig Innes",
    "Paul Jackson",
    "Marc Juarez Miro",
    "Elham Kashefi",
    "Frank Keller",
    "Mohsen Khadem",
    "Ava Khamseh",
    "Aggelos Kiayias",
    "Simon King",
    "Markulf Kohlweiss",
    "Nadin Kokciyan",
    "Taku Komura",
    "Maithilee Kunda",
    "Catherine Lai",
    "Mirella Lapata",
    "Alex Lascarides",
    "Susan Lechelt",
    "John Lee",
    "Changjian Li",
    "Jingjie Li",
    "Wenda Li",
    "Zhibin (Alex) Li",
    "Leonid Libkin",
    "Sam Lindley",
    "John Longley",
    "Adam Lopez",
    "Chris Lu",
    "Christopher Lucas",
    "Tiejun Ma",
    "Oisin Mac Aodha",
    "Walid Magdy",
    "Luo Mai",
    "Mahesh Marina",
    "Richard Mayr",
    "Fiona Mcneill",
    "Pasquale Minervini",
    "Michael Mistry",
    "Brian Mitchell",
    "Iain Murray",
    "Vijay Nagarajan",
    "Siddharth Narayanaswamy",
    "Kia Nazarpour",
    "Milos Nikolic",
    "Michael O'Boyle",
    "Liam O'Connor",
    "Arno Onken",
    "Opeyemi Osakuade",
    "Diego Oyarzun",
    "Jeff Pan",
    "Yuvraj Patel",
    "Paul Patras",
    "Andreas Pieris",
    "Gordon Plotkin",
    "Elizabeth Polgreen",
    "Edoardo Ponti",
    "Ajitha Rajan",
    "Ram Ramamoorthy",
    "Valerio Restocchi",
    "Korin Richmond",
    "Dave Robertson",
    "Judy Robertson",
    "Bjorn Ross",
    "Michael Rovatsos",
    "Don Sannella",
    "Rik Sarkar",
    "Paul Schweizer",
    "Adriana Sejfia",
    "Peggy Series",
    "Laura Sevilla-Lara",
    "Amir Shaikhha",
    "Hiroshi Shimodaira",
    "Ian Simpson",
    "Vanessa Smer Barre",
    "Mohan Sridharan",
    "Ian Stark",
    "Mark Steedman",
    "David Sterratt",
    "Perdita Stevens",
    "Amos Storkey",
    "Kartic Subr",
    "He Sun",
    "David Symons",
    "Hao Tang",
    "Alex Taylor",
    "Henry Thompson",
    "Ivan Titov",
    "Steve Tonneau",
    "Nigel Topham",
    "Amir Vaxman",
    "Antonio Vergari",
    "Sethu Vijayakumar",
    "John Vines",
    "Philip Wadler",
    "Petros Wallden",
    "Barbara Webb",
    "Andrea Weisse",
    "Chris Williams",
    "Maria Wolters",
    "Daniel Woods",
    "Michael Yates",
    "Heather Yorston",
    "Rob van Glabbeek"
]
